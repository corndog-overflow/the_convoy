# %%
from ultralytics import YOLO
import cv2
import tensorflow as tf
import math 
# start webcam

# model
model = YOLO("yolo-Weights/yolov8n.pt")



# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# %%
cap = cv2.VideoCapture(0)
cap.set(3, 1920)
cap.set(4, 1080)

while True:
    passed, img = cap.read()
    results = model(img, stream=True)
    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            #only display objects with label person
            if (classNames[int(box.cls[0])] == "person"):
                # bounding box
                print (int(box.cls[0]))
                x1, y1, x2, y2 = box.xyxy[0]
                # print(int(x1), int(y1), int(x2), int(y2))
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values
                print(x1, y1, x2, y2)
                # put box in camera
                cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

                #drawing centroid
                mid_X = int((x1+x2)/2)
                mid_Y = int((y1+y2)/2)
                center = (mid_X, mid_Y)
                radius = 10
                color = (255, 255, 255)

                cv2.circle(img, center, radius, color, -1)

                # confidence interval
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confidence --->",confidence)

                # class name
                cls = int(box.cls[0])



                print("Class name -->", classNames[cls])

                # object details
                org = [x1, y1]
                font = cv2.FONT_HERSHEY_SIMPLEX
                fontScale = 1
                color = (255, 255, 255)
                thickness = 2

                cv2.putText(img, str(classNames[cls]) + "; confidence:"+str(confidence), org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 133.0ms
# 0
# 485 278 882 715
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.3ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.0ms
# 0
# 429 272 835 713
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.3ms preprocess, 168.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 132.8ms
# 0
# 393 269 793 713
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 132.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.7ms
# 0
# 400 266 792 714
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 116.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.1ms
# 0
# 368 263 788 714
# Confidence ---> 0.89
# Class name --> person
# Speed: 5.5ms preprocess, 118.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 112.5ms
# 0
# 354 263 786 714
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 128.0ms
# 0
# 323 262 788 714
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.1ms preprocess, 128.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.3ms
# 0
# 345 262 794 715
# Confidence ---> 0.87
# Class name --> person
# Speed: 4.5ms preprocess, 115.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# 0
# 398 262 806 715
# Confidence ---> 0.89
# Class name --> person
# Speed: 4.5ms preprocess, 100.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.8ms
# 0
# 398 261 819 714
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.5ms preprocess, 109.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.9ms
# 0
# 392 259 828 714
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.1ms preprocess, 101.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.1ms
# 0
# 392 255 840 714
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.8ms preprocess, 105.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.3ms
# 0
# 411 251 843 716
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 108.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.8ms
# 0
# 439 244 850 717
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.1ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.4ms
# 0
# 446 228 869 716
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.5ms
# 0
# 443 209 889 714
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 102.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.5ms
# 0
# 402 178 904 713
# Confidence ---> 0.92
# Class name --> person
# Speed: 8.1ms preprocess, 103.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.9ms
# 0
# 385 122 909 711
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 108.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 99.9ms
# 0
# 59 32 938 711
# Confidence ---> 0.61
# Class name --> person
# 0
# 344 35 940 715
# Confidence ---> 0.53
# Class name --> person
# Speed: 3.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# 0
# 356 17 950 712
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 99.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 103.0ms
# 0
# 318 3 965 712
# Confidence ---> 0.91
# Class name --> person
# 0
# 1 24 394 705
# Confidence ---> 0.54
# Class name --> person
# Speed: 0.0ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 119.3ms
# 0
# 281 2 934 709
# Confidence ---> 0.79
# Class name --> person
# 0
# 12 1 945 711
# Confidence ---> 0.45
# Class name --> person
# 0
# 0 9 377 702
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.0ms preprocess, 119.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.2ms
# 0
# 4 0 932 710
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 109.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 110.1ms
# Speed: 0.0ms preprocess, 110.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 98.0ms
# Speed: 0.0ms preprocess, 98.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.8ms
# 0
# 26 0 888 703
# Confidence ---> 0.38
# Class name --> person
# Speed: 8.1ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.1ms
# 0
# 10 0 883 705
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.0ms preprocess, 106.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 108.2ms
# 0
# 34 0 875 710
# Confidence ---> 0.48
# Class name --> person
# 0
# 289 5 1280 712
# Confidence ---> 0.39
# Class name --> person
# Speed: 0.0ms preprocess, 108.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# 0
# 12 0 903 708
# Confidence ---> 0.5
# Class name --> person
# Speed: 5.1ms preprocess, 100.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.0ms
# 0
# 9 1 879 711
# Confidence ---> 0.53
# Class name --> person
# Speed: 0.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 109.5ms
# 0
# 7 2 877 710
# Confidence ---> 0.53
# Class name --> person
# Speed: 0.0ms preprocess, 109.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 147.4ms
# Speed: 0.0ms preprocess, 147.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 137.0ms
# 0
# 27 1 859 711
# Confidence ---> 0.89
# Class name --> person
# Speed: 4.6ms preprocess, 137.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 130.5ms
# 0
# 9 1 864 715
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.5ms preprocess, 130.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# 0
# 104 1 868 713
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.8ms preprocess, 101.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 100.1ms
# 0
# 134 2 919 714
# Confidence ---> 0.82
# Class name --> person
# 0
# 0 113 305 710
# Confidence ---> 0.44
# Class name --> person
# Speed: 4.5ms preprocess, 100.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 117.6ms
# 0
# 57 2 982 714
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.1ms preprocess, 117.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.9ms
# 0
# 148 6 975 702
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.0ms preprocess, 108.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.4ms
# 0
# 148 3 966 710
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 104.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.1ms
# 0
# 312 3 950 713
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.7ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.9ms
# 0
# 312 3 950 713
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.3ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.2ms
# 0
# 326 2 937 716
# Confidence ---> 0.95
# Class name --> person
# Speed: 2.8ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 97.9ms
# 0
# 359 44 935 716
# Confidence ---> 0.94
# Class name --> person
# Speed: 5.3ms preprocess, 97.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.7ms
# 0
# 367 78 929 714
# Confidence ---> 0.94
# Class name --> person
# Speed: 5.0ms preprocess, 102.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 104.4ms
# 0
# 382 102 919 714
# Confidence ---> 0.96
# Class name --> person
# Speed: 0.0ms preprocess, 104.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.7ms
# 0
# 392 129 904 715
# Confidence ---> 0.95
# Class name --> person
# Speed: 3.8ms preprocess, 103.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 105.2ms
# 0
# 405 154 884 714
# Confidence ---> 0.95
# Class name --> person
# Speed: 5.0ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 96.0ms
# 0
# 423 169 876 712
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.8ms preprocess, 96.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.9ms
# 0
# 437 175 873 713
# Confidence ---> 0.93
# Class name --> person
# Speed: 5.9ms preprocess, 103.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 112.0ms
# 0
# 450 178 869 712
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.6ms preprocess, 112.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 107.3ms
# 0
# 457 184 872 712
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 107.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 96.4ms
# 0
# 460 187 879 712
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.6ms preprocess, 96.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 95.6ms
# 0
# 467 189 882 709
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.6ms preprocess, 95.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 107.5ms
# 0
# 464 191 879 712
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 107.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 102.4ms
# 0
# 451 193 867 711
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.7ms preprocess, 102.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.5ms
# 0
# 428 196 843 711
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 100.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 108.7ms
# 0
# 413 195 823 707
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 108.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 bed, 106.4ms
# 0
# 376 199 785 711
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 106.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 107.8ms
# 0
# 350 202 769 713
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 107.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 101.7ms
# 0
# 343 203 764 714
# Confidence ---> 0.93
# Class name --> person
# Speed: 5.2ms preprocess, 101.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 102.1ms
# 0
# 352 202 766 714
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 173.7ms
# 0
# 373 199 784 712
# Confidence ---> 0.94
# Class name --> person
# Speed: 5.2ms preprocess, 173.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 95.7ms
# 0
# 400 207 821 710
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.1ms preprocess, 95.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.5ms
# 0
# 407 213 824 712
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.2ms preprocess, 103.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 108.1ms
# 0
# 402 211 821 712
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.3ms preprocess, 108.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 110.0ms
# 0
# 390 206 806 709
# Confidence ---> 0.93
# Class name --> person
# Speed: 6.0ms preprocess, 110.0ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 98.2ms
# 0
# 370 203 782 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.8ms preprocess, 98.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.7ms
# 0
# 351 205 768 713
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.8ms preprocess, 100.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 111.8ms
# 0
# 344 207 763 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.6ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 102.1ms
# 0
# 350 206 766 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.5ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 107.0ms
# 0
# 365 202 779 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.0ms preprocess, 107.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 118.0ms
# 0
# 388 200 802 711
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 118.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 129.2ms
# 0
# 403 204 821 712
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.7ms preprocess, 129.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 115.5ms
# 0
# 412 206 826 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 3.6ms preprocess, 115.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 109.2ms
# 0
# 404 204 818 711
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.1ms preprocess, 109.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 102.8ms
# 0
# 387 201 800 710
# Confidence ---> 0.94
# Class name --> person
# Speed: 4.2ms preprocess, 102.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.9ms
# 0
# 367 200 781 714
# Confidence ---> 0.95
# Class name --> person
# Speed: 2.2ms preprocess, 103.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 102.3ms
# 0
# 350 203 768 712
# Confidence ---> 0.94
# Class name --> person
# Speed: 5.9ms preprocess, 102.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.0ms
# 0
# 342 208 764 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 103.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 101.9ms
# 0
# 344 204 765 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 5.8ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.4ms
# 0
# 357 199 774 712
# Confidence ---> 0.94
# Class name --> person
# Speed: 6.7ms preprocess, 106.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# 0
# 375 198 791 710
# Confidence ---> 0.95
# Class name --> person
# Speed: 5.5ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.5ms
# 0
# 389 201 806 711
# Confidence ---> 0.95
# Class name --> person
# Speed: 4.2ms preprocess, 103.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 96.5ms
# 0
# 393 201 809 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.7ms preprocess, 96.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.1ms
# 0
# 393 201 809 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 100.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 105.8ms
# 0
# 389 199 802 712
# Confidence ---> 0.95
# Class name --> person
# Speed: 5.3ms preprocess, 105.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 109.4ms
# 0
# 378 199 790 712
# Confidence ---> 0.95
# Class name --> person
# Speed: 2.1ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 128.6ms
# 0
# 367 200 775 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.0ms preprocess, 128.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 106.6ms
# 0
# 362 203 769 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 4.8ms preprocess, 106.6ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 128.4ms
# 0
# 331 197 808 707
# Confidence ---> 0.89
# Class name --> person
# Speed: 5.7ms preprocess, 128.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 130.6ms
# 0
# 399 196 890 711
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.7ms preprocess, 130.6ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 134.1ms
# 0
# 332 199 901 713
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.6ms preprocess, 134.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 134.3ms
# 0
# 181 211 892 713
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.3ms preprocess, 134.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 145.1ms
# 0
# 276 201 899 711
# Confidence ---> 0.87
# Class name --> person
# Speed: 4.0ms preprocess, 145.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 111.8ms
# 0
# 331 200 919 713
# Confidence ---> 0.91
# Class name --> person
# Speed: 6.0ms preprocess, 111.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 107.9ms
# 0
# 321 199 947 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 107.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 110.0ms
# 0
# 324 207 942 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# 0
# 234 212 1007 712
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 100.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.7ms
# 0
# 325 206 952 713
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.0ms preprocess, 100.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 105.2ms
# 0
# 321 198 951 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.0ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 106.0ms
# 0
# 315 198 933 712
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 106.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 107.8ms
# 0
# 330 200 882 711
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.2ms preprocess, 107.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.6ms
# 0
# 267 207 842 709
# Confidence ---> 0.76
# Class name --> person
# Speed: 6.1ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 91.3ms
# 0
# 240 206 871 712
# Confidence ---> 0.73
# Class name --> person
# Speed: 5.6ms preprocess, 91.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 97.7ms
# 0
# 241 202 868 710
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.1ms preprocess, 97.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 99.5ms
# 0
# 324 197 914 711
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 99.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 101.5ms
# 0
# 294 196 945 709
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 101.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.4ms
# 0
# 331 198 967 710
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 100.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# 0
# 310 204 1036 712
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 99.9ms
# 0
# 321 198 1029 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 5.7ms preprocess, 99.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 105.9ms
# 0
# 321 196 972 712
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 105.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.1ms
# 0
# 321 196 972 712
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.5ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.1ms
# 0
# 313 196 921 709
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.5ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 97.5ms
# 0
# 309 199 881 710
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.0ms preprocess, 97.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 99.1ms
# 0
# 312 209 780 712
# Confidence ---> 0.58
# Class name --> person
# Speed: 2.8ms preprocess, 99.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# 0
# 164 214 827 714
# Confidence ---> 0.77
# Class name --> person
# Speed: 0.7ms preprocess, 99.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.1ms
# 0
# 174 204 831 713
# Confidence ---> 0.58
# Class name --> person
# Speed: 3.3ms preprocess, 109.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 102.6ms
# 0
# 318 195 906 709
# Confidence ---> 0.89
# Class name --> person
# Speed: 4.5ms preprocess, 102.6ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.5ms
# 0
# 298 195 951 710
# Confidence ---> 0.83
# Class name --> person
# Speed: 4.9ms preprocess, 103.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 100.5ms
# 0
# 333 199 982 712
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.5ms preprocess, 100.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 105.8ms
# 0
# 249 202 1013 712
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.0ms preprocess, 105.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 98.8ms
# 0
# 257 197 1030 712
# Confidence ---> 0.87
# Class name --> person
# Speed: 4.4ms preprocess, 98.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.0ms
# 0
# 323 195 944 708
# Confidence ---> 0.89
# Class name --> person
# Speed: 5.5ms preprocess, 96.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 105.7ms
# 0
# 281 197 875 710
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.1ms preprocess, 105.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 bed, 102.4ms
# 0
# 304 199 828 709
# Confidence ---> 0.86
# Class name --> person
# Speed: 5.2ms preprocess, 102.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 110.1ms
# 0
# 314 207 804 712
# Confidence ---> 0.9
# Class name --> person
# Speed: 7.8ms preprocess, 110.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 102.4ms
# 0
# 161 199 815 708
# Confidence ---> 0.76
# Class name --> person
# Speed: 4.4ms preprocess, 102.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 101.5ms
# 0
# 187 197 823 703
# Confidence ---> 0.59
# Class name --> person
# Speed: 5.3ms preprocess, 101.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 104.9ms
# 0
# 303 202 834 713
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 102.3ms
# 0
# 198 212 839 710
# Confidence ---> 0.88
# Class name --> person
# Speed: 5.4ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 103.1ms
# 0
# 184 210 830 710
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 103.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 106.2ms
# 0
# 169 202 810 711
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.0ms
# 0
# 150 199 787 711
# Confidence ---> 0.86
# Class name --> person
# Speed: 3.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.2ms
# 0
# 137 204 769 709
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 115.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.7ms
# 0
# 163 212 759 713
# Confidence ---> 0.86
# Class name --> person
# Speed: 4.5ms preprocess, 97.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.0ms
# 0
# 163 212 759 713
# Confidence ---> 0.86
# Class name --> person
# Speed: 5.5ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.0ms
# 0
# 167 209 763 712
# Confidence ---> 0.88
# Class name --> person
# Speed: 4.6ms preprocess, 96.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.6ms
# 0
# 165 202 778 710
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.3ms preprocess, 105.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 106.8ms
# 0
# 199 198 795 709
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 106.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 107.0ms
# 0
# 403 197 800 710
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 101.6ms
# 0
# 435 204 797 712
# Confidence ---> 0.89
# Class name --> person
# Speed: 6.0ms preprocess, 101.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 108.0ms
# 0
# 440 207 785 713
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 108.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 99.7ms
# 0
# 475 207 788 712
# Confidence ---> 0.81
# Class name --> person
# Speed: 5.0ms preprocess, 99.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 105.0ms
# 0
# 472 207 800 711
# Confidence ---> 0.67
# Class name --> person
# Speed: 4.9ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.0ms
# 0
# 494 201 806 713
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.9ms
# 0
# 497 177 809 711
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 103.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 96.6ms
# 0
# 470 193 820 714
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.6ms preprocess, 96.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 96.9ms
# 0
# 475 176 809 713
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.9ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 101.9ms
# 0
# 469 193 804 714
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 101.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 110.8ms
# 0
# 472 186 801 714
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.3ms preprocess, 110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 1 bed, 95.4ms
# 0
# 465 192 797 714
# Confidence ---> 0.89
# Class name --> person
# Speed: 4.1ms preprocess, 95.4ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 113.8ms
# 0
# 463 188 794 714
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.8ms preprocess, 113.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 107.2ms
# 0
# 454 193 793 714
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 107.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.6ms
# 0
# 436 197 803 713
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 103.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.1ms
# 0
# 421 190 811 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.1ms preprocess, 100.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 97.5ms
# 0
# 415 183 819 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 4.5ms preprocess, 97.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 106.8ms
# 0
# 415 183 819 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.0ms preprocess, 106.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 112.4ms
# 0
# 413 190 822 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 4.1ms preprocess, 112.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 105.6ms
# 0
# 412 190 825 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 105.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 109.8ms
# 0
# 412 190 825 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 5.0ms preprocess, 109.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 113.1ms
# 0
# 415 191 818 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 113.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 105.0ms
# 0
# 416 190 814 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.5ms
# 0
# 413 190 811 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 4.0ms preprocess, 103.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 105.0ms
# 0
# 413 191 809 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 112.1ms
# 0
# 424 194 791 713
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 112.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 106.9ms
# 0
# 448 197 759 714
# Confidence ---> 0.76
# Class name --> person
# Speed: 0.0ms preprocess, 106.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.5ms
# 0
# 458 201 748 714
# Confidence ---> 0.82
# Class name --> person
# Speed: 4.0ms preprocess, 103.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 98.7ms
# 0
# 458 201 753 714
# Confidence ---> 0.86
# Class name --> person
# Speed: 4.4ms preprocess, 98.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 97.3ms
# 0
# 462 194 752 714
# Confidence ---> 0.84
# Class name --> person
# Speed: 3.8ms preprocess, 97.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 92.3ms
# 0
# 451 173 755 714
# Confidence ---> 0.9
# Class name --> person
# Speed: 7.6ms preprocess, 92.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 106.1ms
# 0
# 449 194 760 714
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 106.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 98.2ms
# 0
# 456 177 759 714
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.8ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.1ms
# 0
# 460 172 767 714
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.0ms preprocess, 103.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 105.9ms
# 0
# 456 179 770 714
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 94.1ms
# 0
# 455 186 773 715
# Confidence ---> 0.89
# Class name --> person
# Speed: 5.4ms preprocess, 94.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 109.4ms
# 0
# 472 179 777 713
# Confidence ---> 0.83
# Class name --> person
# Speed: 4.2ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.7ms
# 0
# 477 180 786 712
# Confidence ---> 0.74
# Class name --> person
# Speed: 0.0ms preprocess, 104.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 106.2ms
# 0
# 480 183 797 714
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.0ms preprocess, 106.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.0ms
# 0
# 512 191 808 712
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.0ms preprocess, 100.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 102.5ms
# 0
# 494 189 813 714
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.0ms preprocess, 102.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.2ms
# 0
# 520 187 817 694
# Confidence ---> 0.76
# Class name --> person
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 158.6ms
# 0
# 519 185 832 714
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.0ms preprocess, 158.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 119.6ms
# 0
# 515 196 843 712
# Confidence ---> 0.84
# Class name --> person
# Speed: 6.2ms preprocess, 119.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 109.9ms
# 0
# 502 204 858 712
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 109.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 99.7ms
# 0
# 486 198 873 713
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.5ms preprocess, 99.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 103.5ms
# 0
# 470 199 877 713
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 103.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 98.8ms
# 0
# 447 202 870 714
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.5ms preprocess, 98.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.3ms
# 0
# 442 202 857 713
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 107.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.0ms
# 0
# 432 201 846 713
# Confidence ---> 0.88
# Class name --> person
# Speed: 4.6ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 106.8ms
# 0
# 424 198 832 713
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.0ms preprocess, 106.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 111.7ms
# 0
# 413 197 816 712
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 111.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 98.7ms
# 0
# 398 196 801 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 4.3ms preprocess, 98.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 100.4ms
# 0
# 399 194 773 713
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.0ms preprocess, 100.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 106.0ms
# 0
# 413 192 760 714
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.1ms preprocess, 106.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.0ms
# 0
# 422 188 745 713
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 97.0ms
# 0
# 426 186 742 711
# Confidence ---> 0.92
# Class name --> person
# Speed: 8.1ms preprocess, 97.0ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 105.6ms
# 0
# 418 183 741 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 5.0ms preprocess, 105.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 99.9ms
# 0
# 408 181 737 714
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.4ms preprocess, 99.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 95.3ms
# 0
# 417 178 724 714
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.5ms preprocess, 95.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 99.6ms
# 0
# 416 175 725 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.4ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 107.6ms
# 0
# 405 170 743 714
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 107.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 107.6ms
# 0
# 399 163 758 714
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 107.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 95.2ms
# 0
# 399 139 764 713
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.1ms preprocess, 95.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.0ms
# 0
# 410 122 786 712
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.5ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 109.4ms
# 0
# 421 105 801 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 4.5ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 96.7ms
# 0
# 420 100 805 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.1ms preprocess, 96.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 108.3ms
# 0
# 410 89 809 713
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 108.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.1ms
# 0
# 400 82 809 714
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 115.8ms
# 0
# 364 66 805 713
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.1ms
# 0
# 338 60 805 715
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.8ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# 0
# 304 49 807 712
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.5ms preprocess, 100.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.9ms
# 0
# 280 43 814 713
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.8ms preprocess, 98.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 109.5ms
# 0
# 266 43 818 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 109.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.7ms
# 0
# 242 50 836 711
# Confidence ---> 0.93
# Class name --> person
# Speed: 6.0ms preprocess, 97.7ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# 0
# 222 57 858 714
# Confidence ---> 0.89
# Class name --> person
# Speed: 5.1ms preprocess, 101.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 102.8ms
# 0
# 187 61 871 713
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 102.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 104.7ms
# 0
# 188 65 865 712
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.5ms preprocess, 104.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.0ms
# 0
# 267 76 857 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 4.2ms preprocess, 106.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 108.5ms
# 0
# 249 81 844 713
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.6ms preprocess, 108.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 103.4ms
# 0
# 245 82 832 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 103.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# 0
# 240 87 820 715
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 101.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.4ms
# 0
# 225 97 814 714
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 102.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 100.0ms
# 0
# 248 108 811 713
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.3ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.0ms
# 0
# 260 107 812 714
# Confidence ---> 0.95
# Class name --> person
# Speed: 4.2ms preprocess, 97.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 110.0ms
# 0
# 263 104 815 714
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# 0
# 251 91 839 713
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.0ms preprocess, 100.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.1ms
# 0
# 245 95 841 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 120.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 chair, 106.4ms
# 0
# 233 105 830 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 5.9ms preprocess, 106.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.8ms
# 0
# 211 112 815 712
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.4ms
# 0
# 199 102 806 713
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.0ms preprocess, 97.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.0ms
# 0
# 191 97 804 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 92.3ms
# 0
# 188 97 800 715
# Confidence ---> 0.94
# Class name --> person
# Speed: 9.3ms preprocess, 92.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.0ms
# 0
# 189 108 796 714
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 106.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# 0
# 191 114 801 714
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.5ms
# 0
# 180 102 809 714
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 103.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 100.2ms
# 0
# 216 93 819 713
# Confidence ---> 0.94
# Class name --> person
# Speed: 4.5ms preprocess, 100.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.5ms
# 0
# 197 93 822 716
# Confidence ---> 0.91
# Class name --> person
# Speed: 6.8ms preprocess, 106.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.3ms
# 0
# 185 97 822 713
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.1ms preprocess, 103.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.4ms
# 0
# 207 97 804 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.0ms preprocess, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.0ms
# 0
# 191 90 792 714
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 107.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 110.1ms
# 0
# 179 86 780 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 8.3ms preprocess, 110.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.3ms
# 0
# 170 83 762 713
# Confidence ---> 0.95
# Class name --> person
# Speed: 5.5ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.2ms
# 0
# 176 85 737 713
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 101.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.1ms
# 0
# 179 88 721 714
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 105.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 119.0ms
# 0
# 287 93 733 713
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.5ms preprocess, 119.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 96.2ms
# 0
# 396 109 775 712
# Confidence ---> 0.92
# Class name --> person
# Speed: 6.2ms preprocess, 96.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.2ms
# 0
# 412 120 702 714
# Confidence ---> 0.87
# Class name --> person
# Speed: 4.5ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 103.9ms
# 0
# 429 120 840 713
# Confidence ---> 0.9
# Class name --> person
# ...
# 0
# 933 9 1279 714
# Confidence ---> 0.93
# Class name --> person
# 0
# 0 51 450 713
# Confidence ---> 0.89
# Class name --> person
# 0
# 344 128 631 712
# Confidence ---> 0.81
# Class name --> person
# 0
# 592 112 982 711
# Confidence ---> 0.68
# Class name --> person
# Speed: 10.6ms preprocess, 185.0ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 204.8ms
# 0
# 954 8 1279 714
# Confidence ---> 0.93
# Class name --> person
# 0
# 504 103 994 713
# Confidence ---> 0.91
# Class name --> person
# 0
# 0 50 453 713
# Confidence ---> 0.9
# Class name --> person
# 0
# 348 135 598 713
# Confidence ---> 0.8
# Class name --> person
# Speed: 8.1ms preprocess, 204.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 306.2ms
# 0
# 0 45 458 713
# Confidence ---> 0.95
# Class name --> person
# 0
# 957 7 1279 713
# Confidence ---> 0.94
# Class name --> person
# 0
# 345 141 611 712
# Confidence ---> 0.85
# Class name --> person
# 0
# 490 105 976 713
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.7ms preprocess, 306.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 193.8ms
# 0
# 944 1 1279 715
# Confidence ---> 0.93
# Class name --> person
# 0
# 0 41 461 711
# Confidence ---> 0.93
# Class name --> person
# 0
# 344 141 599 712
# Confidence ---> 0.83
# Class name --> person
# 0
# 500 96 969 714
# Confidence ---> 0.81
# Class name --> person
# Speed: 8.1ms preprocess, 193.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 216.8ms
# 0
# 935 2 1279 714
# Confidence ---> 0.93
# Class name --> person
# 0
# 0 38 462 711
# Confidence ---> 0.93
# Class name --> person
# 0
# 450 98 978 713
# Confidence ---> 0.88
# Class name --> person
# 0
# 346 136 597 713
# Confidence ---> 0.86
# Class name --> person
# 0
# 96 610 267 719
# Confidence ---> 0.48
# Class name --> person
# Speed: 7.0ms preprocess, 216.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 chair, 2 cell phones, 184.1ms
# 0
# 929 2 1279 713
# Confidence ---> 0.95
# Class name --> person
# 0
# 0 37 460 710
# Confidence ---> 0.88
# Class name --> person
# 0
# 456 96 986 713
# Confidence ---> 0.87
# Class name --> person
# 0
# 341 142 598 714
# Confidence ---> 0.8
# Class name --> person
# Speed: 6.0ms preprocess, 184.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cell phone, 285.1ms
# 0
# 939 4 1279 707
# Confidence ---> 0.92
# Class name --> person
# 0
# 463 99 986 712
# Confidence ---> 0.91
# Class name --> person
# 0
# 0 34 459 715
# Confidence ---> 0.9
# Class name --> person
# 0
# 340 142 586 712
# Confidence ---> 0.73
# Class name --> person
# Speed: 7.5ms preprocess, 285.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cell phone, 190.7ms
# 0
# 940 2 1279 711
# Confidence ---> 0.92
# Class name --> person
# 0
# 0 34 453 713
# Confidence ---> 0.92
# Class name --> person
# 0
# 462 100 984 712
# Confidence ---> 0.92
# Class name --> person
# 0
# 342 134 593 712
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.6ms preprocess, 190.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cell phone, 324.7ms
# 0
# 946 1 1279 712
# Confidence ---> 0.93
# Class name --> person
# 0
# 463 101 986 712
# Confidence ---> 0.93
# Class name --> person
# 0
# 0 30 458 713
# Confidence ---> 0.93
# Class name --> person
# 0
# 341 139 586 713
# Confidence ---> 0.75
# Class name --> person
# Speed: 5.1ms preprocess, 324.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cell phone, 178.8ms
# 0
# 944 1 1279 712
# Confidence ---> 0.93
# Class name --> person
# 0
# 461 99 987 712
# Confidence ---> 0.92
# Class name --> person
# 0
# 0 32 457 711
# Confidence ---> 0.89
# Class name --> person
# 0
# 344 144 597 712
# Confidence ---> 0.65
# Class name --> person
# Speed: 10.2ms preprocess, 178.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cell phone, 184.0ms
# 0
# 942 1 1279 712
# Confidence ---> 0.93
# Class name --> person
# 0
# 465 99 991 713
# Confidence ---> 0.93
# Class name --> person
# 0
# 0 35 388 712
# Confidence ---> 0.91
# Class name --> person
# 0
# 339 145 589 712
# Confidence ---> 0.85
# Class name --> person
# Speed: 5.9ms preprocess, 184.0ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 207.9ms
# 0
# 941 2 1279 711
# Confidence ---> 0.93
# Class name --> person
# 0
# 0 39 355 711
# Confidence ---> 0.93
# Class name --> person
# 0
# 466 100 993 712
# Confidence ---> 0.93
# Class name --> person
# 0
# 336 143 592 710
# Confidence ---> 0.88
# Class name --> person
# Speed: 6.1ms preprocess, 207.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 180.8ms
# 0
# 940 2 1279 712
# Confidence ---> 0.93
# Class name --> person
# 0
# 0 35 424 712
# Confidence ---> 0.92
# Class name --> person
# 0
# 474 101 994 712
# Confidence ---> 0.92
# Class name --> person
# 0
# 332 140 587 710
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.0ms preprocess, 180.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 205.8ms
# 0
# 469 101 991 713
# Confidence ---> 0.93
# Class name --> person
# 0
# 0 37 390 711
# Confidence ---> 0.92
# Class name --> person
# 0
# 933 1 1279 710
# Confidence ---> 0.92
# Class name --> person
# 0
# 330 145 568 711
# Confidence ---> 0.85
# Class name --> person
# Speed: 4.0ms preprocess, 205.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 192.6ms
# 0
# 467 102 994 712
# Confidence ---> 0.93
# Class name --> person
# 0
# 919 2 1279 710
# Confidence ---> 0.93
# Class name --> person
# 0
# 0 35 412 712
# Confidence ---> 0.92
# Class name --> person
# 0
# 331 153 568 711
# Confidence ---> 0.84
# Class name --> person
# Speed: 107.0ms preprocess, 192.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 207.8ms
# 0
# 911 42 1279 711
# Confidence ---> 0.94
# Class name --> person
# 0
# 0 35 363 712
# Confidence ---> 0.94
# Class name --> person
# 0
# 466 102 984 713
# Confidence ---> 0.92
# Class name --> person
# 0
# 344 210 563 708
# Confidence ---> 0.79
# Class name --> person
# Speed: 2.2ms preprocess, 207.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 271.9ms
# 0
# 924 87 1279 711
# Confidence ---> 0.94
# Class name --> person
# 0
# 0 36 355 712
# Confidence ---> 0.94
# Class name --> person
# 0
# 468 96 990 714
# Confidence ---> 0.93
# Class name --> person
# 0
# 417 256 589 711
# Confidence ---> 0.67
# Class name --> person
# 0
# 428 257 582 540
# Confidence ---> 0.36
# Class name --> person
# Speed: 10.6ms preprocess, 271.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 200.1ms
# 0
# 0 36 385 712
# Confidence ---> 0.95
# Class name --> person
# 0
# 933 94 1279 710
# Confidence ---> 0.94
# Class name --> person
# 0
# 465 93 994 714
# Confidence ---> 0.92
# Class name --> person
# 0
# 528 285 603 359
# Confidence ---> 0.38
# Class name --> person
# Speed: 5.1ms preprocess, 200.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.9ms
# 0
# 939 95 1279 711
# Confidence ---> 0.95
# Class name --> person
# 0
# 0 37 450 712
# Confidence ---> 0.94
# Class name --> person
# 0
# 454 54 992 712
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.6ms preprocess, 192.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 322.6ms
# 0
# 0 35 348 711
# Confidence ---> 0.95
# Class name --> person
# 0
# 937 86 1279 711
# Confidence ---> 0.93
# Class name --> person
# 0
# 442 9 999 712
# Confidence ---> 0.92
# Class name --> person
# Speed: 7.7ms preprocess, 322.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.8ms
# 0
# 0 31 350 713
# Confidence ---> 0.95
# Class name --> person
# 0
# 399 3 999 712
# Confidence ---> 0.94
# Class name --> person
# 0
# 934 74 1279 710
# Confidence ---> 0.93
# Class name --> person
# Speed: 7.8ms preprocess, 192.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tie, 206.2ms
# 0
# 941 67 1279 711
# Confidence ---> 0.94
# Class name --> person
# 0
# 0 21 348 713
# Confidence ---> 0.91
# Class name --> person
# 0
# 369 2 991 711
# Confidence ---> 0.71
# Class name --> person
# 0
# 647 3 989 705
# Confidence ---> 0.43
# Class name --> person
# Speed: 8.2ms preprocess, 206.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tie, 189.9ms
# 0
# 0 1 329 713
# Confidence ---> 0.91
# Class name --> person
# 0
# 937 58 1279 710
# Confidence ---> 0.89
# Class name --> person
# 0
# 278 27 751 709
# Confidence ---> 0.59
# Class name --> person
# 0
# 543 3 999 710
# Confidence ---> 0.26
# Class name --> person
# Speed: 4.2ms preprocess, 189.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 223.9ms
# 0
# 0 0 327 711
# Confidence ---> 0.65
# Class name --> person
# 0
# 238 7 748 713
# Confidence ---> 0.43
# Class name --> person
# 0
# 1039 6 1278 698
# Confidence ---> 0.35
# Class name --> person
# 0
# 1 0 743 712
# Confidence ---> 0.31
# Class name --> person
# 0
# 63 1 1252 712
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.0ms preprocess, 223.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tie, 308.4ms
# 0
# 0 3 336 709
# Confidence ---> 0.86
# Class name --> person
# 0
# 232 0 748 710
# Confidence ---> 0.74
# Class name --> person
# 0
# 231 3 1073 710
# Confidence ---> 0.27
# Class name --> person
# Speed: 6.9ms preprocess, 308.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tie, 213.1ms
# 0
# 6 2 442 713
# Confidence ---> 0.9
# Class name --> person
# 0
# 436 2 1278 700
# Confidence ---> 0.56
# Class name --> person
# 0
# 760 375 1278 707
# Confidence ---> 0.32
# Class name --> person
# Speed: 6.3ms preprocess, 213.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 252.1ms
# 0
# 86 1 552 711
# Confidence ---> 0.94
# Class name --> person
# 0
# 728 8 1278 704
# Confidence ---> 0.49
# Class name --> person
# Speed: 14.7ms preprocess, 252.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 206.0ms
# 0
# 105 0 595 713
# Confidence ---> 0.95
# Class name --> person
# 0
# 905 15 1279 710
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.0ms preprocess, 206.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 185.1ms
# 0
# 126 0 618 712
# Confidence ---> 0.95
# Class name --> person
# 0
# 892 13 1279 711
# Confidence ---> 0.94
# Class name --> person
# Speed: 9.6ms preprocess, 185.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 212.0ms
# 0
# 115 5 670 712
# Confidence ---> 0.93
# Class name --> person
# 0
# 845 12 1197 712
# Confidence ---> 0.86
# Class name --> person
# Speed: 5.4ms preprocess, 212.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 358.0ms
# 0
# 63 2 705 710
# Confidence ---> 0.91
# Class name --> person
# 0
# 747 4 1113 712
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.6ms preprocess, 358.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 220.7ms
# 0
# 687 2 1097 711
# Confidence ---> 0.94
# Class name --> person
# 0
# 32 2 731 711
# Confidence ---> 0.91
# Class name --> person
# Speed: 8.2ms preprocess, 220.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 184.7ms
# 0
# 691 9 1041 710
# Confidence ---> 0.91
# Class name --> person
# 0
# 31 1 744 710
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.0ms preprocess, 184.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 208.9ms
# 0
# 23 2 741 712
# Confidence ---> 0.9
# Class name --> person
# 0
# 679 21 986 710
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.3ms preprocess, 208.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 211.8ms
# 0
# 691 29 1041 710
# Confidence ---> 0.93
# Class name --> person
# 0
# 26 1 744 710
# Confidence ---> 0.91
# Class name --> person
# Speed: 7.0ms preprocess, 211.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 326.4ms
# 0
# 693 28 1075 712
# Confidence ---> 0.93
# Class name --> person
# 0
# 23 3 746 711
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.1ms preprocess, 326.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 282.6ms
# 0
# 692 16 1164 712
# Confidence ---> 0.92
# Class name --> person
# 0
# 33 1 748 710
# Confidence ---> 0.91
# Class name --> person
# Speed: 7.8ms preprocess, 282.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 222.5ms
# 0
# 724 4 1212 712
# Confidence ---> 0.93
# Class name --> person
# 0
# 48 2 760 710
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.0ms preprocess, 222.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 186.7ms
# 0
# 78 2 760 711
# Confidence ---> 0.93
# Class name --> person
# 0
# 750 3 1222 713
# Confidence ---> 0.92
# Class name --> person
# Speed: 8.1ms preprocess, 186.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 207.2ms
# 0
# 769 1 1225 711
# Confidence ---> 0.92
# Class name --> person
# 0
# 88 2 765 710
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.2ms preprocess, 207.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 308.8ms
# 0
# 803 5 1276 710
# Confidence ---> 0.93
# Class name --> person
# 0
# 103 1 770 710
# Confidence ---> 0.92
# Class name --> person
# Speed: 8.1ms preprocess, 308.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 206.7ms
# 0
# 169 2 772 710
# Confidence ---> 0.88
# Class name --> person
# 0
# 854 0 1279 705
# Confidence ---> 0.75
# Class name --> person
# Speed: 8.1ms preprocess, 206.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 183.8ms
# 0
# 171 1 765 709
# Confidence ---> 0.92
# Class name --> person
# 0
# 911 3 1278 703
# Confidence ---> 0.89
# Class name --> person
# Speed: 7.3ms preprocess, 183.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 205.1ms
# 0
# 109 1 773 708
# Confidence ---> 0.92
# Class name --> person
# 0
# 946 6 1278 708
# Confidence ---> 0.84
# Class name --> person
# Speed: 5.0ms preprocess, 205.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cat, 181.9ms
# 0
# 177 1 768 709
# Confidence ---> 0.86
# Class name --> person
# 0
# 1026 5 1278 709
# Confidence ---> 0.47
# Class name --> person
# Speed: 5.5ms preprocess, 181.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 223.4ms
# 0
# 0 2 764 710
# Confidence ---> 0.91
# Class name --> person
# Speed: 10.1ms preprocess, 223.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 386.3ms
# 0
# 1 1 762 711
# Confidence ---> 0.89
# Class name --> person
# Speed: 4.4ms preprocess, 386.3ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 188.4ms
# 0
# 10 2 757 710
# Confidence ---> 0.92
# Class name --> person
# Speed: 8.3ms preprocess, 188.4ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 211.0ms
# 0
# 55 1 758 712
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.9ms preprocess, 211.0ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 155.3ms
# 0
# 58 2 757 711
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.5ms preprocess, 155.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 135.0ms
# 0
# 53 2 757 711
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.9ms preprocess, 135.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.4ms
# 0
# 58 2 758 710
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 107.4ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 151.8ms
# 0
# 78 2 759 710
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 151.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 126.8ms
# 0
# 161 0 759 709
# Confidence ---> 0.92
# Class name --> person
# 0
# 912 164 1279 577
# Confidence ---> 0.44
# Class name --> person
# Speed: 0.0ms preprocess, 126.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
